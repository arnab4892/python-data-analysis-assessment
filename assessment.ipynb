# %% [markdown]
# <a href="https://colab.research.google.com/github/arnab4892/python-data-analysis-assessment/blob/main/assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/arnab4892/python-data-analysis-assessment.git
# %cd python-data-analysis-assessment
# Out:
# fatal: destination path 'python-data-analysis-assessment' already exists and is not an empty directory.
# /content/python-data-analysis-assessment

# %%
import os
import pandas as pd

print(os.listdir("data"))
# Out:
# ['messy_numeric_sample.csv', 'employees.csv', 'departments.csv', 'payslips.csv', 'staging_payroll_vendor.csv', 'payroll_runs.csv']
